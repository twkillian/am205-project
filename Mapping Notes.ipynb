# %%
# %matplotlib inline
import numpy as np
from math import *
import matplotlib.pyplot as plt

# %%
myarray = np.loadtxt('popgrid.dat',dtype=str)

# %%
float(myarray[0][0][1:-1])
# Out:
# -70.07889649999998

# %%
temp = myarray[0][1].split(',')

# %%
temp2 = float(temp[0][:-1]), float(temp[1])
temp2
# Out:
# (41.666972, 12.0)

# %%
myarray.shape
# Out:
# (638275,)

# %%
with open('popgrid.txt','w') as fd:
    for ii in range(len(myarray)):
        lon = float(myarray[ii][0][1:-1])
        temp = myarray[ii][1].split(',')
        lat = float(temp[0][:-1])
        pop = float(temp[1])
        print>>fd, lat,lon,pop

# %%
newarray = np.loadtxt('popgrid.txt')

# %%
minLat = min(newarray[:,0])
minLon = min(newarray[:,1])

# %%
minLat, minLon
# Out:
# (41.235144499999997, -73.485917499999999)

# %%
cart_array = 100*(newarray[0::50,0:2] - [minLat,minLon]) # Sample by every 50...
sampled_pop = newarray[0::50]

# %%
plt.figure(figsize=(12,10))
plt.plot(cart_array[:,1], cart_array[:,0],'.')

# %%
len(cart_array)
# Out:
# 3151
